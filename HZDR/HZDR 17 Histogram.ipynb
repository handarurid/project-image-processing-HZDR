# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
df = pd.read_csv('histogram_test.csv', header=None)

# %%
df.head()
# Out:
#           0
# 0  0.022888
# 1  0.025177
# 2  0.024109
# 3  0.025330
# 4  0.024109

# %%
df.hist(bins=40)
plt.title('Histogram')
plt.show()

# %%
df[0].plot.density()
plt.title('Density')
plt.show()

# %%
plt.psd(df[0])
plt.title('PSD')
plt.show()
