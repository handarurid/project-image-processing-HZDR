# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Data.csv')
df = df.iloc[:,1:]

# %%
df['Point 0'].hist(bins=40)

# %%
df['Point 0'].plot.density()

# %%
df['Point 0'].plot.kde()

# %%
plt.psd(df['Point 0'])
plt.show()

# %%
plt.psd(df['Point 1'])
plt.show()

# %%
plt.psd(df['Point 2'])
plt.show()
