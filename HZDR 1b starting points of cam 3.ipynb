# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from scipy import ndimage

# %%
def preprocess_image(filename, angle):
    image = cv2.imread(filename)
    image = increase_brightness(image, value=40)
    image = ndimage.rotate(image, angle)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    _, image = cv2.threshold(image, 210, 255, cv2.THRESH_BINARY)
    binary_image = image / 255
    return binary_image

# %%
def increase_brightness(img, value=30):
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    h, s, v = cv2.split(hsv)

    lim = 255 - value
    v[v > lim] = 255
    v[v <= lim] += value

    final_hsv = cv2.merge((h, s, v))
    img = cv2.cvtColor(final_hsv, cv2.COLOR_HSV2BGR)
    return img

# %% [markdown]
# ### Di bawah ini untuk camera 3b (yang miring 45 derajat)

# %%
plt.figure(figsize=(10,10))

rotated45_image = preprocess_image('cam3_images/CCFL040_10_2000_335_up_a_0000.bmp', -45)

size = 5
rotated45_image[800-size:800+size,600-size:600+size] = 0
rotated45_image[800-size:800+size,625-size:625+size] = 0
rotated45_image[800-size:800+size,650-size:650+size] = 0
rotated45_image[800-size:800+size,675-size:675+size] = 0
rotated45_image[800-size:800+size,700-size:700+size] = 0
rotated45_image[800-size:800+size,725-size:725+size] = 0
rotated45_image[800-size:800+size,750-size:750+size] = 0
rotated45_image[800-size:800+size,775-size:775+size] = 0
rotated45_image[800-size:800+size,800-size:800+size] = 0
rotated45_image[800-size:800+size,825-size:825+size] = 0
rotated45_image[800-size:800+size,850-size:850+size] = 0
rotated45_image[800-size:800+size,875-size:875+size] = 0
rotated45_image[800-size:800+size,900-size:900+size] = 0
rotated45_image[800-size:800+size,925-size:925+size] = 0
rotated45_image[800-size:800+size,950-size:950+size] = 0
rotated45_image[800-size:800+size,975-size:975+size] = 0
rotated45_image[800:800+312,1000-size:1000+size] = 0

#rotated45_image[1000-40:1000+40,525-40:525+40] = 0

plt.yticks(np.arange(0, 1600, 50))
plt.xticks(np.arange(0, 1600, 50), rotation=90)
plt.imshow(rotated45_image)
plt.show()

# %% [markdown]
# ### Di bawah ini untuk camera 3a
# #### 35 deg, y=845, x=525
# #### 25 deg, y=865, x=450
# #### 15 deg, y=870, x=375

# %%
plt.figure(figsize=(10,10))

rotated35_image = preprocess_image('cam3_images/CCFL040_10_2000_335_up_a_0000.bmp', -35)

size = 5

'''rotated45_image[800-size:800+size,600-size:600+size] = 0
rotated45_image[800-size:800+size,625-size:625+size] = 0
rotated45_image[800-size:800+size,650-size:650+size] = 0
rotated45_image[800-size:800+size,675-size:675+size] = 0
rotated45_image[800-size:800+size,700-size:700+size] = 0
rotated45_image[800-size:800+size,725-size:725+size] = 0
rotated45_image[800-size:800+size,750-size:750+size] = 0
rotated45_image[800-size:800+size,775-size:775+size] = 0
rotated45_image[800-size:800+size,800-size:800+size] = 0
rotated45_image[800-size:800+size,825-size:825+size] = 0
rotated45_image[800-size:800+size,850-size:850+size] = 0
rotated45_image[800-size:800+size,875-size:875+size] = 0
rotated45_image[800-size:800+size,900-size:900+size] = 0
rotated45_image[800-size:800+size,925-size:925+size] = 0
rotated45_image[800-size:800+size,950-size:950+size] = 0
rotated45_image[800-size:800+size,975-size:975+size] = 0
rotated45_image[800:800+312,1000-size:1000+size] = 0'''

#rotated35_image = ndimage.rotate(rotated45_image, 10)
rotated35_image[845:845+320,525-size:525+size] = 0

plt.yticks(np.arange(0, 1600, 50))
plt.xticks(np.arange(0, 1600, 50), rotation=90)
plt.imshow(rotated35_image)
plt.show()

# %%
plt.figure(figsize=(10,10))

rotated25_image = preprocess_image('cam3_images/CCFL040_10_2000_335_up_a_0000.bmp', -25)

size = 5

rotated25_image[865:865+320,450-size:450+size] = 0

plt.yticks(np.arange(0, 1600, 50))
plt.xticks(np.arange(0, 1600, 50), rotation=90)
plt.imshow(rotated25_image)
plt.show()

# %%
plt.figure(figsize=(10,10))

rotated15_image = preprocess_image('cam3_images/CCFL040_10_2000_335_up_a_0000.bmp', -15)

rotated15_image[870:870+320,375-size:375+size] = 0

plt.yticks(np.arange(0, 1600, 50))
plt.xticks(np.arange(0, 1600, 50), rotation=90)
plt.imshow(rotated15_image)
plt.show()

# %% [markdown]
# ### Di bawah ini untuk camera 3c (paling kanan)

# %%
binary_image = preprocess_image('cam3_images/CCFL040_10_2000_335_up_a_0000.bmp',0)
size = 5

plt.figure(figsize=(10,10))
# [y,x]
#binary_image[90-size:90+size,200-size:200+size] = 0   # Point A = 90,200
#binary_image[70-size:70+size,400-size:400+size] = 0   # Point B = 70,400
#binary_image[70-size:70+size,600-size:600+size] = 0   # Point C = 70,600
#binary_image[75-size:75+size,800-size:800+size] = 0   # Point D = 75,800
#binary_image[80-size:80+size,1000-size:1000+size] = 0   # Point E = 80,1000

#binary_image[90:90+251,200-size:200+size] = 0
#binary_image[70:70+272,400-size:400+size] = 0
#binary_image[70:70+286,600-size:600+size] = 0
#binary_image[75:75+285,800-size:800+size] = 0
#binary_image[80:80+283,1000-size:1000+size] = 0

'''binary_image[845-size:845+size,150-size:150+size] = 0
binary_image[845-size:845+size,175-size:175+size] = 0
binary_image[840-size:840+size,200-size:200+size] = 0
binary_image[835-size:835+size,225-size:225+size] = 0
binary_image[827-size:827+size,250-size:250+size] = 0
binary_image[819-size:819+size,275-size:275+size] = 0
binary_image[805-size:805+size,300-size:300+size] = 0
binary_image[790-size:790+size,325-size:325+size] = 0
binary_image[775-size:775+size,350-size:350+size] = 0
binary_image[750-size:750+size,375-size:375+size] = 0
binary_image[730-size:730+size,400-size:400+size] = 0
binary_image[710-size:710+size,425-size:425+size] = 0
binary_image[690-size:690+size,450-size:450+size] = 0
binary_image[665-size:665+size,475-size:475+size] = 0
binary_image[630-size:630+size,500-size:500+size] = 0
binary_image[600-size:600+size,525-size:525+size] = 0
binary_image[560-size:560+size,550-size:550+size] = 0
binary_image[550-size:550+size,575-size:575+size] = 0
binary_image[505-size:505+size,600-size:600+size] = 0
binary_image[400-size:400+size,625-size:625+size] = 0
binary_image[380-size:380+size,650-size:650+size] = 0
binary_image[380-size:380+size,675-size:675+size] = 0
binary_image[380-size:380+size,700-size:700+size] = 0
binary_image[380-size:380+size,725-size:725+size] = 0
binary_image[380-size:380+size,750-size:750+size] = 0
binary_image[380-size:380+size,775-size:775+size] = 0
binary_image[380-size:380+size,800-size:800+size] = 0
binary_image[380-size:380+size,825-size:825+size] = 0
binary_image[380-size:380+size,850-size:850+size] = 0
binary_image[380-size:380+size,875-size:875+size] = 0
binary_image[380-size:380+size,900-size:900+size] = 0
binary_image[380-size:380+size,925-size:925+size] = 0
binary_image[380-size:380+size,950-size:950+size] = 0
binary_image[380-size:380+size,975-size:975+size] = 0
binary_image[380-size:380+size,1000-size:1000+size] = 0
binary_image[380-size:380+size,1025-size:1025+size] = 0
binary_image[380-size:380+size,1050-size:1050+size] = 0
binary_image[380-size:380+size,1075-size:1075+size] = 0
binary_image[380-size:380+size,1100-size:1100+size] = 0
'''

binary_image[700-size:700+size,900-size:900+size] = 0
binary_image[715-size:715+size,925-size:925+size] = 0
binary_image[725-size:725+size,950-size:950+size] = 0
binary_image[730-size:730+size,975-size:975+size] = 0
binary_image[740-size:740+size,1000-size:1000+size] = 0
binary_image[750-size:750+size,1025-size:1025+size] = 0
binary_image[760-size:760+size,1050-size:1050+size] = 0
binary_image[765-size:765+size,1075-size:1075+size] = 0
binary_image[765-size:765+size,1100-size:1100+size] = 0


binary_image[700-60:700+size,900-size:900+size] = 0
binary_image[715-81:715+size,925-size:925+size] = 0
binary_image[725-95:725+size,950-size:950+size] = 0
binary_image[730-104:730+size,975-size:975+size] = 0
binary_image[740-118:740+size,1000-size:1000+size] = 0
binary_image[750-131:750+size,1025-size:1025+size] = 0
binary_image[760-size:760+size,1050-size:1050+size] = 0
binary_image[765-size:765+size,1075-size:1075+size] = 0
binary_image[765-size:765+size,1100-size:1100+size] = 0

plt.imshow(binary_image)

# Average height: 302

# %%
point_A = [90,200]
point_B = [70,400]
point_C = [70,600]
point_D = [75,800]
point_E = [80,1000]

# %%
# Start is a coordinate --> [y,x]
def count_pixel(binary_image, start):
    y = start[0]
    x = start[1]
    no_of_pixels = 0
    while binary_image[y,x] == 1:
        y += 1
        no_of_pixels += 1
    
    return no_of_pixels

# %%
binary_image = preprocess_image('CCFL002_1_2000_500_up_cam1_a_post.jpg')
count_pixel(binary_image, point_E)
# Out:
# 283

# %%
def find_boundary(binary_image, points)

# %%
plt.figure(figsize=(10,10))
plt.imshow(preprocess_image('CCFL002_1_2000_500_up_cam1_a_pre.jpg'), cmap='gray')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.imshow(preprocess_image('CCFL002_1_2000_500_up_cam2_a_post.jpg'), cmap='gray')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.imshow(preprocess_image('CCFL002_1_2000_500_up_cam2_a_pre.jpg'), cmap='gray')
plt.show()
